# %%
#####################
####################
################
##############
############
##########
########
#####

# %%
import json
import time
#from requests import Session
import random
from pandas.io.json import json_normalize
import pandas as pd
# import APIClient
import logging
#from datetime import datetime
import re
import multiprocessing
import os
import csv

from PmStatsClient import PmStatsClient

from modules import _QueryModule
from modules import _Constants
from modules import _Ops
from modules import _QueryGenerator
from modules import _DataMapModel
from modules import _VendorProcessQueryProperties
import datetime
from dateutil.relativedelta import relativedelta

# %%
#define pm_ststs_clients
#fdd_regex_list = ["([A-Za-z0-9_]+-[A-Z]{2}[0-9]{4}-[A|B|H|K]_[A-Z0-9]+)"]
#fdd_regex_list = ["([A-Za-z0-9_]+-(GM0103|CM1360|CM0465|AM5001|KU0250|PU0195|KI0046|GM0044|KU0262|KU5019|KI0027|KU0347|KU0418|KU0360|KU0412|KU0394|KU0459|AM0139|TR0003|PU0203|GM0168|PO0063|CM0343|CM0062|CM1145|VA0079|CM1346|GM0839|CM1213|KA0005|KU0424|CM1028|TR0090|KU0284|KU0425|JA0035|JA0111|CM0231|MR0068|GM0313|CM1667|MU0005|CM0521|BA0045|BA0002|KU0403|CM1101|GM0302|KU0419|GM0841|GM0520|BA0008|JA0151|KA0033|CM1061|KU0445|JA0110|CM1103|GM0914|CM1641|PU0062|AN0171|JA0044|GM0560|GM0257|GM0017|GM0047|GM0119|AN0222|AM0171|BA0001|AN0249|GM0838|JA0076|GM5038|CM0585|GM0045|AM0112|AN0092|GM0237|GM0208|GM0261|CM0393|JA0120|CM0063|CM0244|CM0186|VA0039|TM0025|CM1438|GA0146|GA0052|GM0164|CM1519|GM0098|GA0065|KA0082|AM0068|JA0043|GM0093|CM0193|CM0535|KL0046|GM0595|MA0010|CM0759|GM0147|GM0056|CM0447|CM0042|CM0026|CM0588|CM1326|CM0113|GM0032|TM0001|GM0319|GM0250|TM0031|GM0023|CM0429|CM0184|KA0095|JA0007|CM0269|GM0780|GM0761|PU5014|JA0116|GM0252|PO0191|MU5005|TR0117|CM2181|GM5044|KA0059|GM0281|CM0301|CM1122|KI0007|TM0030|AN5033|GM0216|CM0424|GM1007|KL0015|CM0053|GM0126|KI0029|CM0934|PO0088|CM1854|KU0462|AM0148|GM0594|GM5017|GM0107)-[A|B|H|K]_[A-Z0-9]+)"]

pm_stats_client = PmStatsClient("AKIAQQ7ARZ2QEESAVUL7", "hfr2O1OBN7rGdvXxWw4p3q6ADo4Pmn6MpYDzW5di", region="ap-southeast-1")
#define process type
process_type = "HSUM"
#define countrer map

Huawei_counter_map_array = [

    
        {"counter_id": "1526727396", "counter_ref_id": "L.ChMeas.CQI.DL.0", "process_type": process_type},
        {"counter_id": "1526727397", "counter_ref_id": "L.ChMeas.CQI.DL.1", "process_type": process_type},
        {"counter_id": "1526727398", "counter_ref_id": "L.ChMeas.CQI.DL.2", "process_type": process_type},
        {"counter_id": "1526727399", "counter_ref_id": "L.ChMeas.CQI.DL.3", "process_type": process_type},
        {"counter_id": "1526727400", "counter_ref_id": "L.ChMeas.CQI.DL.4", "process_type": process_type},
        {"counter_id": "1526727401", "counter_ref_id": "L.ChMeas.CQI.DL.5", "process_type": process_type},
        {"counter_id": "1526727402", "counter_ref_id": "L.ChMeas.CQI.DL.6", "process_type": process_type},
        {"counter_id": "1526727403", "counter_ref_id": "L.ChMeas.CQI.DL.7", "process_type": process_type},
        {"counter_id": "1526727404", "counter_ref_id": "L.ChMeas.CQI.DL.8", "process_type": process_type},
        {"counter_id": "1526727405", "counter_ref_id": "L.ChMeas.CQI.DL.9", "process_type": process_type},
        {"counter_id": "1526727406", "counter_ref_id": "L.ChMeas.CQI.DL.10", "process_type": process_type},
        {"counter_id": "1526727407", "counter_ref_id": "L.ChMeas.CQI.DL.11", "process_type": process_type},
        {"counter_id": "1526727408", "counter_ref_id": "L.ChMeas.CQI.DL.12", "process_type": process_type},
        {"counter_id": "1526727409", "counter_ref_id": "L.ChMeas.CQI.DL.13", "process_type": process_type},
        {"counter_id": "1526727410", "counter_ref_id": "L.ChMeas.CQI.DL.14", "process_type": process_type},
        {"counter_id": "1526727411", "counter_ref_id": "L.ChMeas.CQI.DL.15", "process_type": process_type},
        {"counter_id": "1526726740", "counter_ref_id": "L.ChMeas.PRB.DL.Used.Avg", "process_type": process_type},
        {"counter_id": "1526728433", "counter_ref_id": "L.ChMeas.PRB.DL.Avail", "process_type": process_type},
        {"counter_id": "1526728956", "counter_ref_id": "L.RA.TA.UE.Index0", "process_type": process_type},
        {"counter_id": "1526728957", "counter_ref_id": "L.RA.TA.UE.Index1", "process_type": process_type},
        {"counter_id": "1526728958", "counter_ref_id": "L.RA.TA.UE.Index2", "process_type": process_type},
        {"counter_id": "1526728959", "counter_ref_id": "L.RA.TA.UE.Index3", "process_type": process_type},
        {"counter_id": "1526728960", "counter_ref_id": "L.RA.TA.UE.Index4", "process_type": process_type},
        {"counter_id": "1526728961", "counter_ref_id": "L.RA.TA.UE.Index5", "process_type": process_type},
        {"counter_id": "1526728962", "counter_ref_id": "L.RA.TA.UE.Index6", "process_type": process_type},
        {"counter_id": "1526728963", "counter_ref_id": "L.RA.TA.UE.Index7", "process_type": process_type},
        {"counter_id": "1526728964", "counter_ref_id": "L.RA.TA.UE.Index8", "process_type": process_type},
        {"counter_id": "1526728965", "counter_ref_id": "L.RA.TA.UE.Index9", "process_type": process_type},
        {"counter_id": "1526728966", "counter_ref_id": "L.RA.TA.UE.Index10", "process_type": process_type},
        {"counter_id": "1526728967", "counter_ref_id": "L.RA.TA.UE.Index11", "process_type": process_type}, 
        {"counter_id": "1526728298", "counter_ref_id": "L.UL.Interference.Avg", "process_type": process_type},
        {"counter_id": "1526728975", "counter_ref_id": "L.Traffic.ActiveUser.Avg", "process_type": process_type},   
        {"counter_id": "1526728976", "counter_ref_id": "L.Traffic.ActiveUser.Max", "process_type": process_type},  
        {"counter_id": "1526727378", "counter_ref_id": "L.Traffic.User.Avg", "process_type": process_type},
        {"counter_id": "1526729005", "counter_ref_id": "L.Thrp.bits.DL.LastTTI", "process_type": process_type},
        {"counter_id": "1526729015", "counter_ref_id": "L.Thrp.Time.DL.RmvLastTTI", "process_type": process_type}, 
        {"counter_id": "1526728261", "counter_ref_id": "L.Thrp.bits.DL", "process_type": process_type},
        {"counter_id": "1526728997", "counter_ref_id": "L.Thrp.Time.Cell.DL.HighPrecision", "process_type": process_type}
      
        ]




# define function for create necessory columns for calculation


def extractids(rowAll):
    # dates extraction
    rowAll['datetime'] = rowAll['datetime'].astype('datetime64[ns]')

    rowAll['date']=rowAll["datetime"].dt.date
    rowAll['time']=rowAll["datetime"].dt.time

    rowAll['date'] = rowAll['date'].astype('datetime64[ns]')

    # necessory ids define - this 
    rowAll['Site_id']=rowAll['group_tag'].str.extract(pat='[A-Za-z0-9_]+-([A-Z]{2}[0-9]{4})-[A-Z]_[A-Z0-9]+')
    
    # environment

    rowAll['Envi']=rowAll['group_tag'].str.extract(pat='[A-Za-z0-9_]+-[A-Z]{2}[0-9]{4}-([A-Z])_[A-Z0-9]+')
    rowAll['split_id']=rowAll['group_tag'].str.extract(pat='[A-Za-z0-9_]+-[A-Z]{2}[0-9]{4}-[A-Z]_([A-Z0-9]+)')
    rowAll['Cell_id']=rowAll['split_id'].str.extract(pat='([0-9])')
    rowAll['Cell_id'].fillna('1',inplace=True)
    rowAll['Sector_L']=rowAll['split_id'].str.extract(pat='([A-Z])')
    
    # calculate PMs cqi, PRB,RATA,Interference, Traffic1,traffic 2, user avg, user vol, cell troughput, user throughput
    rowAll['Ref_Avg_CQI']=((0*rowAll['L.ChMeas.CQI.DL.0'])+(1*rowAll['L.ChMeas.CQI.DL.1'])+(2*rowAll['L.ChMeas.CQI.DL.2'])+(3*rowAll['L.ChMeas.CQI.DL.3'])+(4*rowAll['L.ChMeas.CQI.DL.4'])+(5*rowAll['L.ChMeas.CQI.DL.5'])+(6*rowAll['L.ChMeas.CQI.DL.6'])+(7*rowAll['L.ChMeas.CQI.DL.7'])+(8*rowAll['L.ChMeas.CQI.DL.8'])+(9*rowAll['L.ChMeas.CQI.DL.9'])+(10*rowAll['L.ChMeas.CQI.DL.10'])+(11*rowAll['L.ChMeas.CQI.DL.11'])+(12*rowAll['L.ChMeas.CQI.DL.12'])+(13*rowAll['L.ChMeas.CQI.DL.13'])+(14*rowAll['L.ChMeas.CQI.DL.14'])+(15*rowAll['L.ChMeas.CQI.DL.15']))/(rowAll['L.ChMeas.CQI.DL.0']+rowAll['L.ChMeas.CQI.DL.1']+rowAll['L.ChMeas.CQI.DL.2']+rowAll['L.ChMeas.CQI.DL.3']+rowAll['L.ChMeas.CQI.DL.4']+rowAll['L.ChMeas.CQI.DL.5']+rowAll['L.ChMeas.CQI.DL.6']+rowAll['L.ChMeas.CQI.DL.7']+rowAll['L.ChMeas.CQI.DL.8']+rowAll['L.ChMeas.CQI.DL.9']+rowAll['L.ChMeas.CQI.DL.10']+rowAll['L.ChMeas.CQI.DL.11']+rowAll['L.ChMeas.CQI.DL.12']+rowAll['L.ChMeas.CQI.DL.13']+rowAll['L.ChMeas.CQI.DL.14']+rowAll['L.ChMeas.CQI.DL.15'])
    rowAll['Ref_DL_PRB_utilization']=rowAll['L.ChMeas.PRB.DL.Used.Avg']*100/rowAll['L.ChMeas.PRB.DL.Avail']
    rowAll['Ref_L_RA_TA_UE_Index_All_Approx']=(rowAll['L.RA.TA.UE.Index0']*0.5+rowAll['L.RA.TA.UE.Index1']*2.5+rowAll['L.RA.TA.UE.Index2']*5.5+rowAll['L.RA.TA.UE.Index3']*10.5+rowAll['L.RA.TA.UE.Index4']*19.5+rowAll['L.RA.TA.UE.Index5']*35.5+rowAll['L.RA.TA.UE.Index6']*65.5+rowAll['L.RA.TA.UE.Index7']*135.5+rowAll['L.RA.TA.UE.Index8']*285.5+rowAll['L.RA.TA.UE.Index9']*535.5+rowAll['L.RA.TA.UE.Index10']*835.5+rowAll['L.RA.TA.UE.Index11']*1185.5)/(rowAll['L.RA.TA.UE.Index1']+rowAll['L.RA.TA.UE.Index2']+rowAll['L.RA.TA.UE.Index3']+rowAll['L.RA.TA.UE.Index4']+rowAll['L.RA.TA.UE.Index5']+rowAll['L.RA.TA.UE.Index6']+rowAll['L.RA.TA.UE.Index7']+rowAll['L.RA.TA.UE.Index8']+rowAll['L.RA.TA.UE.Index9']+rowAll['L.RA.TA.UE.Index10']+rowAll['L.RA.TA.UE.Index11'])
    #rowAll['Ref_DL_PRB_utilization']=rowAll['L.ChMeas.PRB.DL.Used.Avg']*100/rowAll['L.ChMeas.PRB.DL.Avail']
    rowAll['L_UL_Interference_Avg']=rowAll['L.UL.Interference.Avg']
    rowAll['L_Traffic_ActiveUser_Avg']=rowAll['L.Traffic.ActiveUser.Avg']
    rowAll['L_Traffic_ActiveUser_Max']=rowAll['L.Traffic.ActiveUser.Max']
    rowAll['Ish_L_User_Avg']=rowAll['L.Traffic.User.Avg']
    rowAll['User_Volume']=(((rowAll['L.Thrp.bits.DL']/8)/1024)/1024)/1024

    rowAll['Ref_L_Cell_Thrp_Kbps_DL']=rowAll['L.Thrp.bits.DL']/rowAll['L.Thrp.Time.Cell.DL.HighPrecision']
    rowAll['Ref_L_User_Thrp_Kbps_DL']=(rowAll['L.Thrp.bits.DL']-rowAll['L.Thrp.bits.DL.LastTTI'])/rowAll['L.Thrp.Time.DL.RmvLastTTI']
    
    return rowAll

# %%
# cell_df - store cel commisioned dates
updf=pd.read_csv('cell_df.csv')
csvoutput12=[['Site_Id','Date','Splittype','Sector_Id','SectorXUserVol','SectorXCellCapacity','SectorXPRB','SectorXUserAvg','SectorXUserThroughput','SectorXCQI','SectorXRATA','SectorXInterference','Split1XUserVol','Split1XCellCapacity','Split1XPRB','Split1XUserAvg','Split1XUserThroughput','Split1XCQI','Split1XRATA','Split1XInterference','Split2XUserVol','Split2XCellCapacity','Split2XPRB','Split2XUserAvg','Split2XUserThroughput','Split2XCQI','Split2XRATA','Split2XInterference']]
csvoutput14=[['Site_Id','Date','Splittype','Sector_Id','SectorAUserVol','SectorACellCapacity','SectorAPRB','SectorAUserAvg','SectorAUserThroughput','SectorACQI','SectorARATA','SectorAInterference','Split1XUserVol','Split1XCellCapacity','Split1XPRB','Split1XUserAvg','Split1XUserThroughput','Split1XCQI','Split1XRATA','Split1XInterference','Split2XUserVol','Split2XCellCapacity','Split2XPRB','Split2XUserAvg','Split2XUserThroughput','Split2XCQI','Split2XRATA','Split2XInterference','Split3XUserVol','Split3XCellCapacity','Split3XPRB','Split3XUserAvg','Split3XUserThroughput','Split3XCQI','Split3XRATA','Split3XInterference','Split4XUserVol','Split4XCellCapacity','Split4XPRB','Split4XUserAvg','Split4XUserThroughput','Split4XCQI','Split4XRATA','Split4XInterference']]
csvoutput24=[['Site_Id','Date','Splittype','Sector_Id','SectorAUserVol','SectACellCapacity','SectAPRB','SectAUserAvg','SectAUserThroughput','SectACQI','SectARATA','SectAInterference','SectorBUserVol','SectorBCellCapacity','SectorBPRB','SectorBUserAvg','SectorBUserThroughput','SectorBCQI','SectorBRATA','SectorBInterference','Split1XUserVol','Split1XCellCapacity','Split1XPRB','Split1XUserAvg','Split1XUserThroughput','Split1XCQI','Split1XRATA','Split1XInterference','Split1XUserVol','Split2XCellCapacity','Split2XPRB','Split2XUserAvg','Split2XUserThroughput','Split2XCQI','Split2XRATA','Split2XInterference','Split3XUserVol','Split3XCellCapacity','Split3XPRB','Split3XUserAvg','Split3XUserThroughput','Split3XCQI','Split3XRATA','Split3XInterference','Split4XUserVol','Split4XCellCapacity','Split4XPRB','Split4XUserAvg','Split4XUserThroughput','Split4XCQI','Split4XRATA','Split4XInterference']]
csvoutputui=[[]]

#filter data for time range, environment, technology, status etc...
df=updf[['cell_name','cell_status','tech','upgrade_date','vendor']]
df['upgrade_date'] = df['upgrade_date'].astype('datetime64[ns]')
df['site_id']=df['cell_name'].str.extract(pat='[A-Za-z0-9_]+-([A-Z]{2}[0-9]{4})-[A-Z]_[A-Z0-9]+')
df['envi']=df['cell_name'].str.extract(pat='[A-Za-z0-9_]+-[A-Z]{2}[0-9]{4}-([A-Z])_[A-Z0-9]+')
df['change_id']=df['cell_name'].str.extract(pat='[A-Za-z0-9_]+-[A-Z]{2}[0-9]{4}-[A-Z]_([0-9A-Z]+)')
df['sec_letter']=df['change_id'].str.extract(pat='([A-Z])')
df['cell_id']=df['cell_name'].str.extract(pat='[A-Za-z0-9_]+-[A-Z]{2}[0-9]{4}-[A-Z]_([0-9])[A-Z]+')


df=df[df['envi']=='H']
#filter upgrade dates
datelim0=datetime.datetime.strptime('2020-06-16','%Y-%m-%d') # change it 16
datelim1=datetime.datetime.strptime('2020-06-25','%Y-%m-%d')

df=df[df['upgrade_date']>datelim0]
df=df[df['upgrade_date']<datelim1]
#fikter technolgy &nstatus
df=df[(df['tech']=='4G-FDD') | (df['tech']=='4G-NBIoT') | (df['tech']=='4G-TDD')]
df=df[df['cell_status']=="Live"]
df=df[df['vendor']=='huawei']


daylist=df['upgrade_date'].astype(str).unique().tolist()


for datex in daylist:
    
    datext=datetime.datetime.strptime(datex,'%Y-%m-%d')
    dfn=df[df['upgrade_date']==datext]
    sitelist=dfn['site_id'].unique()
    sitestr=''

    for i in range(len(sitelist)):
        if (i==0):
            sitestr=sitelist[i]
        sitestr=sitestr+'|'+sitelist[i]

    fdd_regex_list= ["([A-Za-z0-9_]+-("+sitestr+")-H_[A-Z0-9]+)"]
    
    
    
    


# iteration through the df- contain cell upgrade dates
#for i,row in df.iterrows():
    #fdd_regex_list= ["([A-Za-z0-9_]+-("+row['site_id']+")-[H]_[A-Z0-9]+)"]
#    fdd_regex_list=['([A-Za-z0-9_]+-'+str(row['site_id'])+'-H_[A-Z0-9]+)']
    #fdd_regex_list= ["([A-Za-z0-9_]+-("+sitestr+")-[A|B|H|K]_[A-Z0-9]+)"]
    

    #day0=row['upgrade_date']
    #define day limits to query - 
    day0=datext
    #day0=datetime.datetime.strptime(day0,'%Y-%m-%d')
    day1=day0 - relativedelta(days=13)
    day2=day0 - relativedelta(days=5)
    day3=day0 + relativedelta(days=7)
    day4=day0 + relativedelta(days=14)
    day1=str(day1)
    day2=str(day2)
    day3=str(day3)
    day4=str(day4)

    # query week before upgrd
    
    
    respoBef = pm_stats_client.get_stats(day1, day2, "huawei", "4G", Huawei_counter_map_array, "REGEX_EXTRACT", fdd_regex_list)
    respoBef.to_csv('qry/beforedf'+str(datex)+'.csv')
    

    # query aftr upgrd
    respoAf = pm_stats_client.get_stats(day3, day4, "huawei", "4G", Huawei_counter_map_array, "REGEX_EXTRACT", fdd_regex_list)
    respoAf.to_csv('qry/afterdf'+str(datex)+'.csv')
    


    #define output 2d list
    print('Q--------done')
    



    # define necessory columns and get data frames for before and after upgrade
    rowbeforeX=extractids(respoBef)
    rowafterX=extractids(respoAf)
    
    


    siteIdlist=rowbeforeX['Site_id'].unique()

    # go to unique site id
    for i in range(len(siteIdlist)):

        #Tempsiteid=siteIdlist[i]
        #rowAll=rowAllori[rowAllori['Site_id']==siteIdlist[i]]
        #datelim0=datetime.datetime.strptime(day1,'%Y-%m-%d')
        #datelim1=datetime.datetime.strptime(day2,'%Y-%m-%d')
        #datelim2=datetime.datetime.strptime(day3,'%Y-%m-%d')
        #datelim3=datetime.datetime.strptime(day4,'%Y-%m-%d')

        #date0='2019-12-18'

        rowbefore=rowbeforeX[rowbeforeX['Site_id']==siteIdlist[i]]
        rowafter=rowafterX[rowafterX['Site_id']==siteIdlist[i]]
        #rowafter=rowAll[datelim2<rowAll['date'] & rowAll['date']<datelim3]






        #rowbefore=rowAll[rowAll['date']>datelim0]  #>'2019-12-11' & rowAll['datetime']<'2019-12-19']
        #rowbefore=rowbefore[rowbefore['date']<datelim1] 


        #rowbefore.to_csv('rowbefore.csv')


        #rowafter=rowAll[rowAll['date']>datelim2] #>'2020-01-02' & rowAll['datetime']<'2020-01-10']
        #rowafter=rowafter[rowafter['date']<datelim3]
        #rowafter.to_csv('rowafter.csv')

        #print(rowafter)

        #linedata=[siteIdlist[i],day0]




        # for rowbefore df
        # select site environment
        uniqenvilist=rowbefore['Envi'].unique()
        for j in range(len(uniqenvilist)):
            envibdf=rowbefore[rowbefore.loc[:,'Envi']==uniqenvilist[j]]
            enviadf=rowafter[rowafter.loc[:,'Envi']==uniqenvilist[j]]
            sectorlist=envibdf['Sector_L'].unique()
            #print(envibdf)

            # select sector

            for k in range(len(sectorlist)):

                linedata=[siteIdlist[i],day0]



                sectorbdf=envibdf[envibdf.loc[:,'Sector_L']==sectorlist[k]]
                sectoradf=enviadf[enviadf.loc[:,'Sector_L']==sectorlist[k]]
                cellblist=sectorbdf['Cell_id'].unique()
                cellalist=sectoradf['Cell_id'].unique()

                # find for split type comparing cell ids
                splittype='empty'
                if ((len(cellblist)==1 and len(cellalist)==2)):
                    splittype='split'
                elif((len(cellblist)==1 and len(cellalist)==4)):
                    splittype='directMIMO'
                elif((len(cellblist)==2 and len(cellalist)==4)):
                    splittype='MIMO'
                else:
                    splittype='Unidentified'

                #inedata=[siteidlist[i],date0,splittype]
                linedata.extend([splittype,sectorlist[k]])
                #print(linedata)
                print(len(cellblist)==2 and len(cellalist)==4)
                print(sectorlist[k],'---',len(cellblist),len(cellalist),splittype)


                for p in range(len(cellblist)):
                    cellbdf=sectorbdf[sectorbdf.loc[:,'Cell_id']==cellblist[p]]
                    maxhbcol=cellbdf.groupby('date')['L.Traffic.User.Avg'].idxmax()

                    print(cellblist,'---',cellblist[p],'----after--')
                    print(maxhbcol)

                    maxhdf=cellbdf.loc[maxhbcol]
                    uvolmean=maxhdf['User_Volume'].mean()
                    cellcapmean = maxhdf['Ref_L_Cell_Thrp_Kbps_DL'].mean()
                    cellPRBmean=maxhdf['Ref_DL_PRB_utilization'].mean()
                    cellusrmean=maxhdf['L_Traffic_ActiveUser_Avg'].mean()
                    cellUsrTmean=maxhdf['Ref_L_User_Thrp_Kbps_DL'].mean()
                    cellCQImean=maxhdf['Ref_Avg_CQI'].mean()
                    cellRTAmean=maxhdf['Ref_L_RA_TA_UE_Index_All_Approx'].mean()
                    cellIntmean=maxhdf['L_UL_Interference_Avg'].mean()

                    linedata.extend([uvolmean,cellcapmean,cellPRBmean,cellusrmean,cellUsrTmean,cellCQImean,cellRTAmean,cellIntmean])



                for q in range(len(cellalist)):
                    celladf=sectoradf[sectoradf.loc[:,'Cell_id']==cellalist[q]]
                    maxhacol=celladf.groupby('date')['L.Traffic.User.Avg'].idxmax()#rset_index()

                    print(cellalist,'---',cellalist[q],'----after--')
                    print(maxhacol)

                    maxhadf=celladf.loc[maxhacol]
                    uvolmean=maxhdf['User_Volume'].mean()
                    cellcapmean = maxhadf['Ref_L_Cell_Thrp_Kbps_DL'].mean()
                    cellPRBmean=maxhadf['Ref_DL_PRB_utilization'].mean()
                    cellusrmean=maxhadf['L_Traffic_ActiveUser_Avg'].mean()
                    cellUsrTmean=maxhadf['Ref_L_User_Thrp_Kbps_DL'].mean()
                    cellCQImean=maxhadf['Ref_Avg_CQI'].mean()
                    cellRTAmean=maxhadf['Ref_L_RA_TA_UE_Index_All_Approx'].mean()
                    cellIntmean=maxhadf['L_UL_Interference_Avg'].mean()



                    linedata.extend([uvolmean,cellcapmean,cellPRBmean,cellusrmean,cellUsrTmean,cellCQImean,cellRTAmean,cellIntmean])


                print(linedata)


                if(splittype=='split'):
                    csvoutput12.append(linedata)
                elif(splittype=='directMIMO'):
                     csvoutput14.append(linedata)
                elif(splittype=='MIMO'):
                    csvoutput24.append(linedata)
                else:
                    csvoutputui.append(linedata)

                #print(linedata)





with open('Split12.csv','w',newline='') as myoutput1:
  writer=csv.writer(myoutput1)
  writer.writerows(csvoutput12)
    
with open('Split14.csv','w',newline='') as myoutput2:
  writer=csv.writer(myoutput2)
  writer.writerows(csvoutput14)
    
with open('Split24.csv','w',newline='') as myoutput3:
  writer=csv.writer(myoutput3)
  writer.writerows(csvoutput24)

    
with open('Splitui.csv','w',newline='') as myoutput4:
  writer=csv.writer(myoutput4)
  writer.writerows(csvoutputui)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (9,12,14,19,20,30,32,34,36,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
